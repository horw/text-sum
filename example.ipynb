# %%
from comment_processor import data_parser

# %%
df = data_parser.read_file()

# %%
i=0
for row in df[df['root_id'].isna()].iloc():
    i+=1
    print(row['id'])
    if i ==10:
        break
# Out:
# _UYt9yJFck0
# ZZDu5IRiI9g
# VJ0dk0dxRRk
# Irzr95K6T9A
# 9-GWe3L8efY
# dJNj3etmShQ
# ABHScKpjdMg
# BI5sGNU7400
# mTrl-YbrVz0
# HhxA9usv_HE

# %%
for c in df[df['root_id']=='VJ0dk0dxRRk'].iloc():
    print(c['text'])
# Out:
# Чувак, гениально. Я с тобой. Только надо придумать как быть с холодцом который я вчера наварил.
# А что с ним делать?) Съесть) Раз готов уже
# Да, а что плохого в макаронах?)
#
# И любой рацион может быть в кайф) Главное - привыкнуть.
# Нет, не только, но я привел пример на девушки. Посчитать рацион для мужчины?
# Что именно нет?)
#  @igoryan_i   С2 яйца например и кетчуп
# А когда борщ есть?
# Пример рациона на 1 день. Скажу сразу, можно разнообразить и сделать 2-3-4 разных дня по продукта, но одинаковых по БЖУ и стоимости.
#
# Завтрак:
# - 2 яйца
# - 300мл молоко 2,5%
# - 30г сыр
# - 30г орехи
#
# Обед:
# - 150г куриного филе
# - 30г кетчуп
# - 60г макароны
# - 200г капуста
#
# Ужин:
# - 60г рис
# - 100г брокколи
# - 60г кукуруза
# - 100г скумбрия
#
# Итого на неделю 2561 рубль
#
# Напишите в комменты, с колько вы денег тратите на еду в месяц/в неделю?
# ...
